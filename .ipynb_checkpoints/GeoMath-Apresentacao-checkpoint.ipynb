# %%
from geomath import figure, point

# %%
a = point.Point(0,0)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-915edab1a0ee> in <module>()
# ----> 1 a = Point(0,0)
#
# NameError: name 'Point' is not defined
